# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
quantity = int(input("Informe o tamanho do vetor: "))

Bx = np.random.randint(120,150, quantity)

print(Bx)
# Out:
# Informe o tamanho do vetor: 5
# [141 142 126 143 121]

# %%
plt.plot(Bx)
plt.show()
